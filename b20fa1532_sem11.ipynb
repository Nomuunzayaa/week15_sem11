# %%
#Даалгавар нэг
import numpy as np
import matplotlib.pyplot as plt
 
 
Languages = ['Python','C','Java','C++','C#','Visual Basic','Java Script']
 
data = [12.47,11.59,10.99,8.83,6.39,5.86,2.21]

explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.2, 0.0)
 
# Creating color parameters
colors = ( "orange", "cyan", "brown",
          "grey", "indigo", "beige", 'green')


fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts = ax.pie(data,
                                  autopct = lambda pct: func(pct, data),
                                  explode = explode,
                                  labels = cars,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))
 
 
plt.setp(autotexts, size = 10, weight ="bold")
ax.set_title("Programming Language Ratings TIOBE, May 2022")
 
plt.show()

# %%
# Даалгавар нэг

import matplotlib.pyplot as plt
   
Languages = ['Python','C','Java','C++','C#','Visual Basic','Java Script']
Rating = [12.47,11.59,10.99,8.83,6.39,5.86,2.21]

New_Colors = ['green','blue','purple','brown','teal','red','yellow','orange']
plt.bar(Languages, Rating, color=New_Colors)
plt.title('Programming Language Ratings of TIOBE, May 2022', fontsize=14)
plt.xlabel('Programming Languages', fontsize=14)
plt.ylabel('Rating, percentage', fontsize=14)
plt.grid(True)
plt.show()

# %%
#Даалгавар хоёр
import numpy as np
import matplotlib.pyplot as plt
 
 
Languages = ['Python','Java','Java Script','C#','C++','PHP','R']
 
data = [27.86,17.86,9.17,7.62,7.0,5.86,2.21]

explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.2, 0.0)
 
# Creating color parameters
colors = ( "orange", "cyan", "brown",
          "grey", "indigo", "beige", 'green')


fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts = ax.pie(data,
                                  autopct = lambda pct: func(pct, data),
                                  explode = explode,
                                  labels = cars,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))
 
 
plt.setp(autotexts, size = 10, weight ="bold")
ax.set_title("PYPL PopularitY of Programming Language,2022")
 
plt.show()

# %%
# Даалгавар хоёр

import matplotlib.pyplot as plt
   
Languages = ['Python','Java','Java Script','C#','C++','PHP','R']
Rating = [27.86,17.86,9.17,7.62,7.0,5.86,2.21]

New_Colors = ['green','blue','purple','brown','teal','red','yellow','orange']
plt.bar(Languages, Rating, color=New_Colors)
plt.title('PYPL PopularitY of Programming Language,2022', fontsize=14)
plt.xlabel('Programming Languages', fontsize=14)
plt.ylabel('Rating, percentage', fontsize=14)
plt.grid(True)
plt.show()
